# %% [markdown]
# # Phase 2: Co-occurrence Network Construction
#
# To be completed in Phase 2:
# - SparCC compositional-aware correlation
# - Genus-level co-occurrence networks
# - Network metrics and community structure
