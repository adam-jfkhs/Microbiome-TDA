# %% [markdown]
# # Phase 4: Neurotransmitter Pathway Topology
#
# This notebook analyzes the topology of NT-producing microbial subnetworks:
# - Score each sample's NT production potential (serotonin, GABA, dopamine, SCFA)
# - Extract and analyze NT-specific subnetwork topology
# - Cross-feeding analysis: inter-pathway topology
# - Correlate subnetwork topology with NT scores and mood outcomes (AGP)
