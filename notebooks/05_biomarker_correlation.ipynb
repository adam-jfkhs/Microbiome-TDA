# %% [markdown]
# # Phase 5: Mycobiome and AMR Disruption Analysis
#
# This notebook characterizes how fungi and AMR carriers disrupt NT-network topology:
# - Mycobiome disruption: partition by fungal burden, compare persistence diagrams
# - Per-fungus disruption effects (Candida, Aspergillus, Malassezia)
# - AMR resilience simulation: progressive removal of susceptible taxa
# - Topological tipping point identification
# - HGT edge detection in AMR carrier subnetwork
