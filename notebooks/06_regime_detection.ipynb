# %% [markdown]
# # Phase 6: Regime Detection via Sliding Window Topology
#
# This notebook performs sliding window topological analysis:
# - Order samples by NT production gradient
# - Sliding window persistence computation
# - Detect topological regime transitions
# - Compare topological transitions with compositional shifts
# - Wasserstein distance between consecutive persistence diagrams
