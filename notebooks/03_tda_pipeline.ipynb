# %% [markdown]
# # Phase 3: Persistent Homology Pipeline
#
# This notebook applies TDA to co-occurrence networks:
# - Persistent homology on full co-occurrence network
# - Persistent homology on NT-specific subnetworks
# - Feature extraction: Betti curves, persistence landscapes, entropy
# - Comparison across sample groups (healthy vs. disease, high vs. low NT score)
