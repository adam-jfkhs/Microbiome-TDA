# %% [markdown]
# # Phase 7: Biomarker Correlation and Gut-Brain Axis
#
# This notebook correlates topological features with outcomes:
# - NT production scores vs. topological features
# - AGP self-reported mental health outcomes vs. topology
# - Permeability markers and SCFA profiles
# - Cross-cohort validation (HMP, AGP, curatedMetagenomicData)
# - ML classification: topological features vs. diversity metrics
