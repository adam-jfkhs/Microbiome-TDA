# %% [markdown]
# # Phase 2: Co-occurrence Network Construction
#
# This notebook builds co-occurrence networks and extracts NT-specific subnetworks:
# - Spearman correlation on CLR-transformed abundances
# - Full genus-level co-occurrence networks
# - NT pathway subnetwork extraction (serotonin, GABA, dopamine, SCFA)
# - Network metrics and community structure comparison
