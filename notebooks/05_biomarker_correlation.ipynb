# %% [markdown]
# # Phase 5: Biomarker Correlation
#
# To be completed in Phase 5:
# - Correlate topological features with permeability markers
# - Correlate with neuropeptide levels
# - ML classification using topological features
