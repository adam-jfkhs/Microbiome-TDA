# %% [markdown]
# # Phase 3: TDA Pipeline
#
# To be completed in Phase 3:
# - Persistent homology on co-occurrence networks
# - Feature extraction (Betti curves, landscapes, entropy)
# - Comparison across sample groups
